# %% [markdown]
# # Histogram ve Yoğunluk

# %%
import seaborn as sns
diamonds = sns.load_dataset('diamonds')
df= diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
sns.displot(df.price,bins=10);

# %%
# ?sns.displot
# Out:
# Signature:
# sns.displot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     row=None,
#     col=None,
#     weights=None,
#     kind='hist',
#     rug=False,
#     rug_kws=None,
#     log_scale=None,
#     legend=True,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     color=None,
#     col_wrap=None,
#     row_order=None,
#     col_order=None,
#     height=5,
#     aspect=1,
#     facet_kws=None,
#     **kwargs,
# )
# Docstring:
# Figure-level interface for drawing distribution plots onto a FacetGrid.
#
# This function provides access to several approaches for visualizing the
# univariate or bivariate distribution of data, including subsets of data
# defined by semantic mapping and faceting across multiple subplots. The
# ``kind`` parameter selects the approach to use:
#
# - :func:`histplot` (with ``kind="hist"``; the default)
# - :func:`kdeplot` (with ``kind="kde"``)
# - :func:`ecdfplot` (with ``kind="ecdf"``; univariate-only)
#
# ...

# %%
sns.displot(df.price,kde= True,bins=25)

# %%
sns.displot(df.price, kind= 'kde')
sns.displot(df.price)

# %%
# ?sns.displot
# Out:
# Signature:
# sns.displot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     row=None,
#     col=None,
#     weights=None,
#     kind='hist',
#     rug=False,
#     rug_kws=None,
#     log_scale=None,
#     legend=True,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     color=None,
#     col_wrap=None,
#     row_order=None,
#     col_order=None,
#     height=5,
#     aspect=1,
#     facet_kws=None,
#     **kwargs,
# )
# Docstring:
# Figure-level interface for drawing distribution plots onto a FacetGrid.
#
# This function provides access to several approaches for visualizing the
# univariate or bivariate distribution of data, including subsets of data
# defined by semantic mapping and faceting across multiple subplots. The
# ``kind`` parameter selects the approach to use:
#
# - :func:`histplot` (with ``kind="hist"``; the default)
# - :func:`kdeplot` (with ``kind="kde"``)
# - :func:`ecdfplot` (with ``kind="ecdf"``; univariate-only)
#
# ...

# %%
sns.kdeplot(df.price,fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
#  # histogram ve yoğunluk çaprazlamaları

# %%
(sns
 .FacetGrid(df,
               hue='cut',
              height=5,
              xlim= (0,10000),
              )
 .map(sns.kdeplot,'price',fill=True).add_legend())
#ideal >premium >very good> good >fair

# %%
(sns
 .FacetGrid(df,
               hue='clarity',
              height=5,
              xlim= (0,20000),
              )
 .map(sns.kdeplot,'price',fill=True).add_legend());
# clarity: temizliği, berraklığı (I1(worst), SI2,SI1,VS2,VVS2,VVS1,IF(best))

# %%
(sns
 .FacetGrid(df,
               hue='color',
              height=5,
              xlim= (0,20000),
              )
 .map(sns.kdeplot,'price',fill=True).add_legend());
# : color (From j()worst to D(best))

# %%
sns.catplot(x='cut', y='price',hue="color", kind= 'point', data= df )

# %% [markdown]
# # Boxplot

# %% [markdown]
# ### Veri Seti Hikayesi
# * tip: Dolar cinsinden bahşiş,
# * total_bill: dolar cinsinden fatura,
# * sex : faturayı ödeyen kişinin cinsiyeti,
# *  smoker: partide sigara içenlerin olup olmadığı,
# * day : haftanın günü,
# * time: günün zamanı,
# * size: partinin büyüklüğü.

# %%
import seaborn as sns
tips=sns.load_dataset('tips')
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.day.values
# Out:
# ['Sun', 'Sun', 'Sun', 'Sun', 'Sun', ..., 'Sat', 'Sat', 'Sat', 'Sat', 'Thur']
# Length: 244
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df.isnull().any()
# Out:
# total_bill    False
# tip           False
# sex           False
# smoker        False
# day           False
# time          False
# size          False
# dtype: bool

# %%
df.groupby('smoker').count()
# Out:
#         total_bill  tip  sex  day  time  size
# smoker
# Yes             93   93   93   93    93    93
# No             151  151  151  151   151   151

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.barplot(x='size', y= 'tip',data=df)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
df.groupby(['size','total_bill'])['tip'].mean()
# Out:
# size  total_bill
# 1     3.07          1.00
#       7.25          1.00
#       8.58          1.92
#       10.07         1.83
# 2     5.75          1.00
#                     ...
# 5     41.19         5.00
# 6     27.05         5.00
#       29.80         4.20
#       34.30         6.70
#       48.17         5.00
# Name: tip, Length: 238, dtype: float64

# %%
##acaba sigara içenler daha mı çok tip bırakıyor.
sns.barplot(x='smoker',y='tip',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
df.groupby(['smoker'])['tip'].mean()
# Out:
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %%
## smokerlar çok az bir farkla daha çok tip bırakıyormuş ancak acaba bu durum party size ile ilintili mi ?
## bunu görmek için party size ile sigara içenleri çaprazzlayıp tip ile ilişkelendireceğim.
sns.barplot(hue='smoker',
            x='size',
           y=df.tip,
           data=df)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.loc[lambda df: df['smoker'] == 'Yes']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4
# 58        11.24  1.76    Male    Yes  Sat  Dinner     2
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2
# 61        13.81  2.00    Male    Yes  Sat  Dinner     2
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [93 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# *************

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %% [markdown]
# # BoxPlot

# %%
sns.boxplot(x= df.total_bill)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(y= df.total_bill)
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxenplot(y= df.total_bill)
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# ### boxplot çaprazlamaları

# %%
## hangi günler daha fazla kazanıyoruz acaba

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
sns.boxplot(x= df.day,y= df.total_bill, data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxenplot(x= df.day,y= df.total_bill, hue='time', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(hue='size',
            x= df.day,
           y= df.total_bill,
           data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.barplot( hue='time',
            x= df.day,
           y= df.total_bill,
           data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
### sabah mı akşam mı daha çok kazanıyoruz

# %%
sns.boxplot(y= df.total_bill, x='time', data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# ### Violin

# %%
sns.violinplot(y = df.total_bill, linewidth=5) ## dağılım ve yoğunluk için güzel bir grafik
# Out:
# <Axes: ylabel='total_bill'>

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
sns.catplot(y= 'total_bill', kind='violin', data=df, linewidth=5)

# %%
##Violin Çaprazlamaları
sns.violinplot(y= df.day , kind='violin', x=df.total_bill, data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(y= df.day , kind='violin', x=df.total_bill, data=df, hue= df.sex)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# # Korelasyon Grafikleri
# ### Scatter plot

# %%
import seaborn as sns
import pandas as pd
tips= sns.load_dataset('tips')
df=tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["time"] = df["time"].replace("Dinner", 0)
df["time"] = df["time"].replace("Lunch", 1)

df["sex"] = df["sex"].replace("Female", 1)
df["sex"] = df["sex"].replace("Male", 0)

df["smoker"] = df["smoker"].replace("Yes", 1)
df["smoker"] = df["smoker"].replace("No", 0)

# %%
df.time=df.time.astype('int')
df["sex"] = df["sex"].astype("int")
df.smoker = df.smoker.astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    int32
#  3   smoker      244 non-null    int32
#  4   day         244 non-null    category
#  5   time        244 non-null    int32
#  6   size        244 non-null    int64
# dtypes: category(1), float64(2), int32(3), int64(1)
# memory usage: 9.1 KB

# %%
df.time.value_counts()
# Out:
# 0    176
# 1     68
# Name: time, dtype: int64

# %%
sns.scatterplot(x= df.total_bill, y = df.tip);

# %% [markdown]
# # Korelasyon Çaprazlamaları

# %%
sns.scatterplot(x= df.total_bill, y = df.tip);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.scatterplot(x= df.total_bill, y = df.tip, hue= df.time);

# %%
sns.scatterplot(x= df.total_bill, y = df.tip, hue= df.time, style= df.time);

# %%
sns.scatterplot(x= df.total_bill, y = df.tip, hue= df.day, style= df.time);

# %%
sns.scatterplot(x= df.total_bill, y = df.tip, size= df['size'],hue= df['size']);

# %% [markdown]
# ## Doğrusal İlişkinin Gösterilmesi

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x= 'total_bill' , y= 'tip', data=df);

# %%
# ?sns.lmplot
# Out:
# Signature:
# sns.lmplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     col=None,
#     row=None,
#     palette=None,
#     col_wrap=None,
#     height=5,
#     aspect=1,
#     markers='o',
#     sharex=None,
#     sharey=None,
#     hue_order=None,
#     col_order=None,
#     row_order=None,
#     legend=True,
#     legend_out=None,
#     x_estimator=None,
#     x_bins=None,
#     x_ci='ci',
#     scatter=True,
#     fit_reg=True,
#     ci=95,
#     n_boot=1000,
#     units=None,
#     seed=None,
#     order=1,
#     logistic=False,
#     lowess=False,
#     robust=False,
#     logx=False,
#     x_partial=None,
#     y_partial=None,
#     truncate=True,
#     x_jitter=None,
#     y_jitter=None,
#     scatter_kws=None,
#     line_kws=None,
#     facet_kws=None,
# )
# Docstring:
# Plot data and regression model fits across a FacetGrid.
#
# This function combines :func:`regplot` and :class:`FacetGrid`. It is
# ...

# %%
sns.lmplot(x= 'total_bill' , y= 'tip',hue='time', data=df);

# %%
sns.lmplot(x= 'total_bill' , y= 'tip',hue='smoker', data=df);

# %%
sns.lmplot(x= 'total_bill' , y= 'tip',hue='day', data=df);

# %%
sns.lmplot(x= 'total_bill' , y= 'tip',hue='smoker', col='time' ,data=df);

# %%
sns.lmplot(x= 'total_bill' , y= 'tip',hue='smoker', col='time' ,data=df,row='sex');

# %% [markdown]
# # Scatter Plot Matrisi

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
df= iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
sns.pairplot(df); ###toz bulutu gibiyse ilişki yok demektir. birbirinden farklı köşelerden kümeleniyorsa çaprazlamalar ile o durumlara odaklanılmalı.

# %%
sns.pairplot(df,hue='species');

# %%
sns.pairplot(df,hue='species', markers= ['o','s','D']);

# %% [markdown]
# ### grafiğe doğru işleme

# %%
sns.pairplot(df,kind='reg')

# %%
sns.pairplot(df,hue='species', markers= ['o','s','D'],kind='reg');

# %% [markdown]
# # Heat Map

# %% [markdown]
# ## Veri seti Hikayesi

# %%
import seaborn as sns
flights= sns.load_dataset('flights')
df= flights.copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df.shape
# Out:
# (144, 3)

# %%
df.describe().T
# Out:
#             count         mean         std     min      25%     50%      75%  \
# year        144.0  1954.500000    3.464102  1949.0  1951.75  1954.5  1957.25
# passengers  144.0   280.298611  119.966317   104.0   180.00   265.5   360.50
#
#                max
# year        1960.0
# passengers   622.0

# %%
df.year.value_counts()
# Out:
# 1949    12
# 1950    12
# 1951    12
# 1952    12
# 1953    12
# 1954    12
# 1955    12
# 1956    12
# 1957    12
# 1958    12
# 1959    12
# 1960    12
# Name: year, dtype: int64

# %%
sns.scatterplot(x=df.year ,y= df.passengers, hue=df.month);

# %%
df= df.pivot('month', 'year','passengers')
# Out:
# C:\Users\ycanf\AppData\Local\Temp\ipykernel_10388\1015158509.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df= df.pivot('month', 'year','passengers')

# %%
sns.heatmap(df)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df,annot=True, fmt='d')
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(df,annot=True, fmt='d',linewidths=0.8);

# %% [markdown]
# # Çizgi Grafik

# %%
import seaborn as sns
fmri = sns.load_dataset('fmri')
df = fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
df.describe().T
# Out:
#             count     mean       std       min      25%       50%        75%  \
# timepoint  1064.0  9.00000  5.479801  0.000000  4.00000  9.000000  14.000000
# signal     1064.0  0.00354  0.093930 -0.255486 -0.04607 -0.013653   0.024293
#
#                  max
# timepoint  18.000000
# signal      0.564985

# %%
df.event.value_counts()
# Out:
# stim    532
# cue     532
# Name: event, dtype: int64

# %%
df.region.value_counts()
# Out:
# parietal    532
# frontal     532
# Name: region, dtype: int64

# %%
df.timepoint.value_counts()
# Out:
# 18    56
# 10    56
# 4     56
# 5     56
# 6     56
# 2     56
# 8     56
# 7     56
# 3     56
# 11    56
# 14    56
# 12    56
# 13    56
# 0     56
# 15    56
# 16    56
# 9     56
# 17    56
# 1     56
# Name: timepoint, dtype: int64

# %%
df.timepoint.describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df.groupby('timepoint')['signal'].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby('signal').count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby('timepoint')['signal'].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# ...

# %%
sns.lineplot(x= df.timepoint, y=df.signal);

# %% [markdown]
# ### çaprazlamaları

# %%
sns.lineplot(x= df.timepoint, y=df.signal,hue=df.event);

# %%
sns.lineplot(x= df.timepoint, y=df.signal,hue=df.event , style=df.event);

# %%
sns.lineplot(x= df.timepoint,
             y=df.signal,
             hue=df.event,
             style=df.event,
            markers=True,
            dashes = False);

# %%
sns.lineplot(x= df.timepoint,
             y=df.signal,
             hue=df.region,
             style=df.event,
            markers=True,
            dashes = False);

# %% [markdown]
# ### Basit Zaman Serisi Grafiği Oluşturulması

# %%
# !pip install pandas_datareader
import pandas_datareader as pr
# Out:
# ...
#      ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#      ---------- ---------------------------- 30.7/109.5 kB 1.4 MB/s eta 0:00:01
#      -------------------- ---------------- 61.4/109.5 kB 825.8 kB/s eta 0:00:01
#      ------------------------------- ----- 92.2/109.5 kB 880.9 kB/s eta 0:00:01
#      ------------------------------------ 109.5/109.5 kB 708.7 kB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as wb

# %%
df =  wb.DataReader('AAPL', start='2019-1-15', end ='2023-1-15')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1008.000000  1008.000000  1008.000000  1008.000000  1008.000000
# mean    111.490127   112.870541   110.163286   111.572770   109.860955
# std      42.716421    43.240470    42.143315    42.698895    42.709977
# min      37.567501    38.347500    37.512501    38.174999    36.640785
# 25%      67.195625    68.724998    66.472498    67.821873    66.074228
# 50%     124.555000   125.904999   122.956249   124.783752   122.703503
# 75%     147.014996   148.767502   145.577499   147.044994   145.690037
# max     182.630005   182.940002   179.119995   182.009995   179.953903
#
#              Volume
# count  1.008000e+03
# mean   1.111184e+08
# std    5.227213e+07
# min    3.519590e+07
# 25%    7.703408e+07
# 50%    9.651245e+07
# 75%    1.272658e+08
# max    4.265100e+08

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-15   37.567501   38.347500   37.512501   38.267502   36.729572
# 2019-01-16   38.270000   38.970001   38.250000   38.735001   37.178268
# 2019-01-17   38.549999   39.415001   38.314999   38.965000   37.399025
# 2019-01-18   39.375000   39.470001   38.994999   39.205002   37.629391
# 2019-01-22   39.102501   39.182499   38.154999   38.325001   36.784760
# ...                ...         ...         ...         ...         ...
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  129.426575
# 2023-01-10  130.259995  131.259995  128.119995  130.729996  130.003342
# 2023-01-11  131.250000  133.509995  130.460007  133.490005  132.748016
# 2023-01-12  133.880005  134.259995  131.440002  133.410004  132.668457
# 2023-01-13  132.029999  134.919998  131.660004  134.759995  134.010941
#
#                Volume
# Date
# 2019-01-15  114843600
# 2019-01-16  122278800
# 2019-01-17  119284800
# ...

# %%
df.shape
# Out:
# (1008, 6)

# %%
df.Volume.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.Open.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
kapanis = df.Close

# %%
kapanis.index=pd.DatatimeIndex(kapanis.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[199], line 1
# ----> 1 kapanis.index=pd.DatatimeIndex(kapanis.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'DatatimeIndex'

# %%
kapanis
# Out:
# Date
# 2019-01-15     38.267502
# 2019-01-16     38.735001
# 2019-01-17     38.965000
# 2019-01-18     39.205002
# 2019-01-22     38.325001
#                  ...
# 2023-01-09    130.149994
# 2023-01-10    130.729996
# 2023-01-11    133.490005
# 2023-01-12    133.410004
# 2023-01-13    134.759995
# Name: Close, Length: 1008, dtype: float64

# %%
kapanis.index
# Out:
# DatetimeIndex(['2019-01-15', '2019-01-16', '2019-01-17', '2019-01-18',
#                '2019-01-22', '2019-01-23', '2019-01-24', '2019-01-25',
#                '2019-01-28', '2019-01-29',
#                ...
#                '2022-12-30', '2023-01-03', '2023-01-04', '2023-01-05',
#                '2023-01-06', '2023-01-09', '2023-01-10', '2023-01-11',
#                '2023-01-12', '2023-01-13'],
#               dtype='datetime64[ns]', name='Date', length=1008, freq=None)

# %%
kapanis.index = pd.DatetimeIndex(kapanis.index)

# %%
kapanis.head()
# Out:
# Date
# 2019-01-15    38.267502
# 2019-01-16    38.735001
# 2019-01-17    38.965000
# 2019-01-18    39.205002
# 2019-01-22    38.325001
# Name: Close, dtype: float64

# %% [markdown]
# ### Bölüm sonu değerlendirmesi
# * Dağılım Grafikleri
# * Korelasyon Grafikleri
# * Çizgi Grafik
# * Basit Zaman Serisi
#
# -------------------------------
# * Kategorik değişkenler için Stün Grafik(Bar plot)
# * Sayısal geğişkenler için Histogram, Box Plot, Violin

# %%
df.isnull().values.any()
# Out:
# False

# %%
# ?pd.Categorical
# Out:
# Init signature:
# pd.Categorical(
#     values,
#     categories=None,
#     ordered=None,
#     dtype: 'Dtype | None' = None,
#     fastpath: 'bool' = False,
#     copy: 'bool' = True,
# ) -> 'None'
# Docstring:
# Represent a categorical variable in classic R / S-plus fashion.
#
# `Categoricals` can only take on only a limited, and usually fixed, number
# of possible values (`categories`). In contrast to statistical categorical
# variables, a `Categorical` might have an order, but numerical operations
# (additions, divisions, ...) are not possible.
#
# All values of the `Categorical` are either in `categories` or `np.nan`.
# Assigning values outside of `categories` will raise a `ValueError`. Order
# is defined by the order of the `categories`, not lexical order of the
# values.
#
# Parameters
# ----------
# values : list-like
#     The values of the categorical. If categories are given, values not in
#     categories will be replaced with NaN.
# ...

# %%
# ?pd.Categori
# Out:
# Object `pd.Categori` not found.

# %%
df.Open.value_counts().count()
# Out:
# 971
